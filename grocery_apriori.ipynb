# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from copy import deepcopy
tqdm.pandas()

df = pd.read_csv('./Groceries_dataset.csv')

df.insert(0, 'tid', df.apply(lambda row: f'{row["Member_number"]} {row["Date"]}', axis='columns'))
df.drop(['Member_number', 'Date'], axis='columns', inplace=True)
display(df.head(3))
print(f'Number of raw transactions: {len(df)}')
# Out:
#                tid itemDescription
# 0  1808 21-07-2015  tropical fruit
# 1  2552 05-01-2015      whole milk
# 2  2300 19-09-2015       pip fruit
# Number of raw transactions: 38765

# %%
items = df['itemDescription'].drop_duplicates().to_list()
tids = df['tid'].drop_duplicates().to_list()
print(f'Kinds of items: {len(items)}')
print(f'Number of tids: {len(tids)}')
# Out:
# Kinds of items: 167
# Number of tids: 14963

# %%
binary = np.zeros((len(tids), len(items)), dtype=int)
binary = pd.DataFrame(binary, index=tids, columns=items, dtype=int)

def counter(row): binary.loc[row[0], row[1]] = 1

df.progress_apply(counter, axis='columns')

display(binary.head(3))
# Out:
#   0%|          | 0/38765 [00:00<?, ?it/s]
#                  tropical fruit  whole milk  pip fruit  other vegetables  \
# 1808 21-07-2015               1           0          0                 0
# 2552 05-01-2015               1           1          0                 0
# 2300 19-09-2015               0           0          1                 1
#
#                  rolls/buns  pot plants  citrus fruit  beef  frankfurter  \
# 1808 21-07-2015           1           0             0     0            0
# 2552 05-01-2015           0           0             0     0            0
# 2300 19-09-2015           0           0             0     0            0
#
#                  chicken  ...  flower (seeds)  rice  tea  salad dressing  \
# 1808 21-07-2015        0  ...               0     0    0               0
# 2552 05-01-2015        0  ...               0     0    0               0
# 2300 19-09-2015        0  ...               0     0    0               0
#
#                  specialty vegetables  pudding powder  ready soups  \
# 1808 21-07-2015                     0               0            0
# 2552 05-01-2015                     0               0            0
# 2300 19-09-2015                     0               0            0
#
#                  make up remover  toilet cleaner  preservation products
# 1808 21-07-2015                0               0                      0
# 2552 05-01-2015                0               0                      0
# 2300 19-09-2015                0               0                      0
#
# [3 rows x 167 columns]

# %%
MIN_SUP = 10

abandoned = {}
over_min_sup = {}

def check_support(row): return int(sum(row) == len(row))

for it_idx in tqdm(range(len(items))):
    item = [items[it_idx]]
    sup  = binary[item].apply(check_support, axis='columns').sum()

    key = ', '.join(item)
    if key in abandoned.keys(): continue

    if sup >= MIN_SUP:
        over_min_sup[key] = 0
    else:
        abandoned[key] = 0
        continue

    for it_jdx in range(len(items)):
        print(f'progressing {it_jdx:3d} / {len(items):3d}', end='\r')
        item.append(items[it_jdx])
        item.sort()
        key = ', '.join(item)

        if key in abandoned.keys():
            item.remove(items[it_jdx])
            continue
        elif key in over_min_sup.keys():
            continue

        sup = binary[item].apply(check_support, axis='columns').sum()

        if sup >= MIN_SUP:
            over_min_sup[key] = 0
        else:
            abandoned[key] = 0
            item.remove(items[it_jdx])
            continue

print(f'Number of itemsets that exceed MIN_SUP: {len(over_min_sup)}')
# Out:
#   0%|          | 0/167 [00:00<?, ?it/s]
# Number of itemsets that exceed MIN_SUP: 411

# %%
import pickle

with open('./result.pkl', 'wb') as file:
    pickle.dump(over_min_sup, file)

# %%
with open('./result.pkl', 'rb') as file:
    result = pickle.load(file)

    print(f'List of items that exceed MIN_SUP: {list(result.keys())}')
# Out:
# List of items that exceed MIN_SUP: ['tropical fruit', 'tropical fruit, tropical fruit', 'tropical fruit, tropical fruit, whole milk', 'other vegetables, tropical fruit, tropical fruit, whole milk', 'whole milk', 'tropical fruit, whole milk', 'tropical fruit, whole milk, whole milk', 'other vegetables, tropical fruit, whole milk, whole milk', 'pip fruit', 'pip fruit, tropical fruit', 'pip fruit, pip fruit, tropical fruit', 'other vegetables', 'other vegetables, tropical fruit', 'other vegetables, tropical fruit, whole milk', 'other vegetables, other vegetables, tropical fruit, whole milk', 'rolls/buns', 'rolls/buns, tropical fruit', 'rolls/buns, tropical fruit, whole milk', 'rolls/buns, rolls/buns, tropical fruit, whole milk', 'pot plants', 'pot plants, whole milk', 'pot plants, pot plants, whole milk', 'citrus fruit', 'citrus fruit, tropical fruit', 'citrus fruit, citrus fruit, tropical fruit', 'beef', 'beef, tropical fruit', 'beef, beef, tropical fruit', 'frankfurter', 'frankfurter, tropical fruit', 'frankfurter, frankfurter, tropical fruit', 'chicken', 'chicken, tropical fruit', 'chicken, chicken, tropical fruit', 'butter', 'butter, tropical fruit', 'butter, butter, tropical fruit', 'fruit/vegetable juice', 'fruit/vegetable juice, tropical fruit', 'fruit/vegetable juice, fruit/vegetable juice, tropical fruit', 'packaged fruit/vegetables', 'packaged fruit/vegetables, rolls/buns', 'packaged fruit/vegetables, packaged fruit/vegetables, rolls/buns', 'chocolate', 'chocolate, tropical fruit', 'chocolate, chocolate, tropical fruit', 'specialty bar', 'specialty bar, tropical fruit', 'specialty bar, specialty bar, tropical fruit', 'butter milk', 'butter milk, tropical fruit', 'butter milk, butter milk, tropical fruit', 'bottled water', 'bottled water, tropical fruit', 'bottled water, bottled water, tropical fruit', 'yogurt', 'tropical fruit, yogurt', 'tropical fruit, whole milk, yogurt', 'tropical fruit, whole milk, yogurt, yogurt', 'sausage', 'sausage, tropical fruit', 'sausage, sausage, tropical fruit', 'brown bread', 'brown bread, tropical fruit', 'brown bread, brown bread, tropical fruit', 'hamburger meat', 'hamburger meat, tropical fruit', 'hamburger meat, hamburger meat, tropical fruit', 'root vegetables', 'root vegetables, tropical fruit', 'root vegetables, root vegetables, tropical fruit', 'pork', 'pork, tropical fruit', 'pork, pork, tropical fruit', 'pastry', 'pastry, tropical fruit', 'pastry, pastry, tropical fruit', 'canned beer', 'canned beer, tropical fruit', 'canned beer, canned beer, tropical fruit', 'berries', 'berries, tropical fruit', 'berries, berries, tropical fruit', 'coffee', 'coffee, tropical fruit', 'coffee, coffee, tropical fruit', 'misc. beverages', 'misc. beverages, whole milk', 'misc. beverages, misc. beverages, whole milk', 'ham', 'ham, tropical fruit', 'ham, ham, tropical fruit', 'turkey', 'turkey, whole milk', 'turkey, turkey, whole milk', 'curd cheese', 'curd cheese, curd cheese', 'red/blush wine', 'red/blush wine, whole milk', 'red/blush wine, red/blush wine, whole milk', 'frozen potato products', 'frozen potato products, frozen potato products', 'flour', 'flour, tropical fruit', 'flour, flour, tropical fruit', 'sugar', 'sugar, tropical fruit', 'sugar, sugar, tropical fruit', 'frozen meals', 'frozen meals, tropical fruit', 'frozen meals, frozen meals, tropical fruit', 'herbs', 'herbs, whole milk', 'herbs, herbs, whole milk', 'soda', 'soda, tropical fruit', 'soda, tropical fruit, whole milk', 'soda, soda, tropical fruit, whole milk', 'detergent', 'detergent, tropical fruit', 'detergent, detergent, tropical fruit', 'grapes', 'grapes, tropical fruit', 'grapes, grapes, tropical fruit', 'processed cheese', 'processed cheese, whole milk', 'processed cheese, processed cheese, whole milk', 'fish', 'fish, fish', 'sparkling wine', 'sparkling wine, sparkling wine', 'newspapers', 'newspapers, tropical fruit', 'newspapers, newspapers, tropical fruit', 'curd', 'curd, tropical fruit', 'curd, curd, tropical fruit', ' ...
